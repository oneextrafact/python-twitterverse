# %% [markdown]
# # Finding Guido

# %%
## Finding Guido
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
import os
from tweepy import Client, Paginator

bearer_token = os.environ.get("TWITTER_BEARER_TOKEN")
client = Client(bearer_token)

# %% [markdown]
# We'll start by looking at the network of Guido van Rossum, creator of Python and former "Benevolent Dictator for Life".

# %%
user_response = client.get_user(username="gvanrossum", user_fields=["description", "location", "public_metrics"])

# %%
gvr = user_response[0].id
user_response[0].public_metrics
# Out:
# {'followers_count': 268158,
#  'following_count': 514,
#  'tweet_count': 3553,
#  'listed_count': 4702}

# %% [markdown]
# Who does Guido Van Rossum follow? Originally I made the mistake of using "subscriptions" instead of "following", don't do that! He has almost 270K followers. Also, because I find it really confusing to talk about subscriptions and following, I'm going to refer to the accounts that GVR follows as his "subscriptions". GVR subscribes to just over 500 acccounts. Conveniently, the user objects from tweepy map very nicely to pandas dataframes. A little pandas magic with json_normalize lets us explode the "public_metrics" dictionary into new columns in our frame.

# %%
import pandas as pd

def get_subscriptions_df(id):
    """ 
    Function retrieves subscriptions (accounts that a user is following) for a given user id. 
    Function uses pagination if the user account has more than 1000 subscriptions, which is the limit 
    of what the Twitter api will return in one call. 
    """
    subscriptions = []
    for subscription in Paginator(client.get_users_following, id, user_fields=["description", "location", "public_metrics"], max_results=1000):
        subscriptions.extend(subscription.data)
    subscriptions_df = pd.DataFrame(subscriptions)
    
    # public metrics is a dictionary containing tweet and follower counts. 
    # we merge it with the original dataframe. 
    subscriptions_df = subscriptions_df.merge(
        pd.json_normalize(subscriptions_df.public_metrics), left_index=True, right_index=True).\
        drop("public_metrics", axis="columns")
    subscriptions_df["subscriber"] = id
    return subscriptions_df

# %%
gvr_subscriptions_df = get_subscriptions_df(gvr)
gvr_subscriptions_df.head()
# Out:
#                                          description          id  \
# 0  I work @Microsoft, making Python more awesome ...    14076724
# 1  Intl. Relations & MPP Grad 🌍 noob intersection...   187196955
# 2  Creator of @datasetteproj, co-creator Django. ...       12497
# 3  Partner Software Architect at Microsoft on .NE...    19481808
# 4  The #1 Python-focused podcast covering the peo...  3098427092
#
#             location                        name         username  \
# 0        Redmond, WA                    John Lam         john_lam
# 1             Berlin  Camila Gutiérrez (she/her)  Mariacamilagl30
# 2  San Francisco, CA              Simon Willison           simonw
# 3            Redmond           David Fowler 🇧🇧🇺🇸        davidfowl
# 4   Portland, OR USA         Talk Python Podcast       TalkPython
#
#    followers_count  following_count  tweet_count  listed_count  subscriber
# 0             4406              586         6182           294    15804774
# 1              695              444          259             9    15804774
# 2            41380             5174        41106          1594    15804774
# 3           103795             1318        61361          1607    15804774
# 4            61473             4043         6076          1342    15804774

# %% [markdown]
# We can take a look around at the accounts that Guido is following. They have a very wide range of "subscribers", from 16 to 19,250,000. At the top end, some of the accounts are for celebrities, including:
#
# - Edward Snowden
# - Samantha Power, former US Ambassador to the UN
# - Dave Matthews
# - Grant Imahara
# - Leonard Nimoy
#
# We can also see a lot of organizations, such as Meta, BBC Breaking News, the Mars Rover, etc. For both sets of accunts, it is interesting that so many of these accounts have very small subscription counts of their own, though, much more in line with typical people. Al Gore, for instance, has 2.9 million subscribers but is subscribing to just 40 accounts himself.
#
# We are interested in the subscriptions for these accounts because if one of them is following GVR back, it's a pretty crucial indicator that they are part of the python universe. If we find such a person, we're also interested in who they follow because they are likely to be part of the community as well, and it gives us a sense of where they are / what they're interested in in the Python ecosystem.
#
# We are left with a problem, though. To find out if someone is following GVR back, we need to get their list of subscriptions This would leave us 508,982 user records to sort through! Even getting that list would be a difficult problem. The twitter api will return a max of 1000 subscriptions per call, and there is a rate limit of 15 calls in 15 minutes. Getting the entire list, then, would take a long time and would need to be babysat constantly. To get under this limit, we will need to take a different approach. In this case, we want to see just how many people have more than the 1000 paging limit.

# %%
gvr_subscriptions_df.query("""following_count > 1000""")
# Out:
#                                            description          id  \
# 2    Creator of @datasetteproj, co-creator Django. ...       12497
# 3    Partner Software Architect at Microsoft on .NE...    19481808
# 4    The #1 Python-focused podcast covering the peo...  3098427092
# 5    Python, Cloud and OSS at Microsoft. Author of ...    18185983
# 13   Symmathecist. Engineering Manager of Developer...       25103
# ..                                                 ...         ...
# 502  @missionbit board member & past lead instructo...      755178
# 507  Googler who looks after Open Source. Dad, Husb...       44423
# 508  Frequent fliers know lie-flat options in coach...    15341387
# 511  She/her \nGeek Bridge addict \nGarden to Table...     8799612
# 513                     Free, GNU, and other stuff too    14466201
#
#                  location                                 name       username  \
# 2       San Francisco, CA                       Simon Willison         simonw
# 3                 Redmond                    David Fowler 🇧🇧🇺🇸      davidfowl
# 4        Portland, OR USA                  Talk Python Podcast     TalkPython
# 5       Sydney, Australia                   Anthony Shaw 🇦🇺🤝🇺🇦  anthonypjshaw
# 13          St. Louis, MO                     Jessica Joy Kerr      jessitron
# ..                    ...                                  ...            ...
# 502     San Francisco, CA                         Bob Ippolito        etrepum
# 507      Washington State                         Chris DiBona        cdibona
# 508          New York, NY                          Asya Kamsky        asya999
# 511       Sillycon Valley  annaraven is so tired of this shit.      annaraven
# 513  40.628997,-74.031682                              freegnu        freegnu
#
#      followers_count  following_count  tweet_count  listed_count  subscriber
# 2              41380             5174        41106          1594    15804774
# 3             103795             1318        61361          1607    15804774
# 4              61473             4043         6076          1342    15804774
# 5              21153             2827        19483           499    15804774
# 13             37994             2426        21012          1265    15804774
# ..               ...              ...          ...           ...         ...
# 502             5060             3145        16985           275    15804774
# 507            41803             3046        20642          1673    15804774
# 508             1585             1200         9338            80    15804774
# 511             1281             2145        20224            77    15804774
# 513              227             1616         2070             9    15804774
#
# [127 rows x 10 columns]

# %% [markdown]
# Surely there's a more elegant way to do this

# %%
subscription_frames = []

sub1k_subscriber
# call the people with <1000 followers first, 
for i in

# %%
python_subscriptions_df = gvr_subscriptions_df[gvr_subscriptions_df.description.str.contains("ython")].copy()

# %%
user_ids = python_subscriptions_df.query("""following_count < 750""").id.values

# %%
from time import sleep
subscriptions_frames = []

for i in range(len(subscriptions_frames), len(subscription_ids), 15):
    for user_id in user_ids[i:i+15]:
        subscriptions_frames.append(get_subscriptions_df(user_id))
        sleep(1000)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /usr/local/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File /usr/local/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /usr/local/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/.local/lib/python3.10/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /usr/local/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File /usr/local/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /usr/local/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In [55], line 6
#       4 for i in range(len(subscriptions_frames), len(subscription_ids), 15):
#       5     for user_id in user_ids[i:i+15]:
# ----> 6         subscriptions_frames.append(get_subscriptions_df(user_id))
#       7         sleep(1000)
#
# Cell In [4], line 10, in get_subscriptions_df(id)
#       4 """
#       5 Function retrieves subscriptions (accounts that a user is following) for a given user id.
#       6 Function uses pagination if the user account has more than 1000 subscriptions, which is the limit
#       7 of what the Twitter api will return in one call.
#       8 """
#       9 subscriptions = []
# ---> 10 for subscription in Paginator(client.get_users_following, id, user_fields=["description", "location", "public_metrics"], max_results=1000):
#      11     subscriptions.extend(subscription.data)
#      12 subscriptions_df = pd.DataFrame(subscriptions)
#
# File ~/.local/lib/python3.10/site-packages/tweepy/pagination.py:98, in PaginationIterator.__next__(self)
#      95 else:
#      96     self.kwargs["pagination_token"] = pagination_token
# ---> 98 response = self.method(*self.args, **self.kwargs)
#     100 self.previous_token = response.meta.get("previous_token")
#     101 self.next_token = response.meta.get("next_token")
#
# File ~/.local/lib/python3.10/site-packages/tweepy/client.py:2129, in Client.get_users_following(self, id, user_auth, **params)
#    2090 def get_users_following(self, id, *, user_auth=False, **params):
#    2091     """get_users_following( \
#    2092         id, *, expansions=None, max_results=None, pagination_token=None, \
#    2093         tweet_fields=None, user_fields=None, user_auth=False \
#    (...)
#    2127     https://developer.twitter.com/en/docs/twitter-api/users/follows/api-reference/get-users-id-following
#    2128     """
# -> 2129     return self._make_request(
#    2130         "GET", f"/2/users/{id}/following", params=params,
#    2131         endpoint_parameters=(
#    2132             "expansions", "max_results", "pagination_token",
#    2133             "tweet.fields", "user.fields"
#    2134         ), data_type=User, user_auth=user_auth
#    2135     )
#
# File ~/.local/lib/python3.10/site-packages/tweepy/client.py:126, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     122 def _make_request(self, method, route, params={}, endpoint_parameters=None,
#     123                   json=None, data_type=None, user_auth=False):
#     124     request_params = self._process_params(params, endpoint_parameters)
# --> 126     response = self.request(method, route, params=request_params,
#     127                             json=json, user_auth=user_auth)
#     129     if self.return_type is requests.Response:
#     130         return response
#
# File ~/.local/lib/python3.10/site-packages/tweepy/client.py:83, in BaseClient.request(self, method, route, params, json, user_auth)
#      74     headers["Authorization"] = f"Bearer {self.bearer_token}"
#      76 log.debug(
#      77     f"Making API request: {method} {host + route}\n"
#      78     f"Parameters: {params}\n"
#      79     f"Headers: {headers}\n"
#      80     f"Body: {json}"
#      81 )
# ---> 83 with self.session.request(
#      84     method, host + route, params=params, json=json, headers=headers,
#      85     auth=auth
#      86 ) as response:
#      87     log.debug(
#      88         "Received API response: "
#      89         f"{response.status_code} {response.reason}\n"
#      90         f"Headers: {response.headers}\n"
#      91         f"Content: {response.content}"
#      92     )
#      94     if response.status_code == 400:
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
len(subscriptions_frames)
# Out:
# 5

# %%
gvr_subscriptions_df.sort_values(by="followers_count").tail(50)
# Out:
#                                            description          id  \
# 342  Tweets about SciPy (Scientific Python) and rel...   254791849
# 320  A high-level Python Web framework that encoura...   191225303
# 204                 Videos and podcasts by @BradyHaran   393621632
# 400  NYC gay techie. Founder of Fog Creek, Trello, ...    15948437
# 89   Programmer, coach coach, artist, pokerist, sin...    16891384
# 12   CEO of Epic Games. We make games and to make o...  1686323288
# 377                                                       74979757
# 148  Apparently still a film director.\nDoesn't lik...   421944319
# 363  Creator of @jquery, Chief Software Architect a...      752673
# 19                               I draw the comic xkcd    21146468
# 240  We work to ensure the internet remains a publi...   106682853
# 383                             Founder/CEO of Dropbox    14225267
# 410  The #TalksAtGoogle Program hosts innovators, w...    31925790
# 252  Open Programs at Twitter.\n\nLots of projects ...   376825877
# 404  Twidroyd is discontinued. As alternative we su...    16465507
# 448                                       CTO @ Amazon      113963
# 277  The Official Twitter Account of Michael Dorn a...   561754773
# 90   Author, speaker, and general loud mouth on Sof...    16665197
# 361  Law professor, activist, citizen, father (in r...    11388132
# 360  Director of W3C (https://t.co/uyt4YeYD5u), the...    84351228
# 153                    here to change the face of tech   430995737
# 304  #LearnWithoutLimits on Coursera. Access online...   352053266
# 391  The Python Software Foundation is the non-prof...    63873759
# 322  We're the Electronic Frontier Foundation. We d...        4816
# 387  Used to be at Google, then DC, now in Toronto....     3080761
# 112  We make inexpensive, small computers for home,...   302666251
# 190  This account has been archived. You can now fo...  1615463502
# 139  I build things and make videos about it. Busin...   897861037
# 412                                                       16381279
# 293  Host of White Rabbit Project on Netflix, forme...    28521141
# 375                                               Dad.    33152005
# 409  Digital & social media updates from @CDCgov. #...    15587500
# 281    Make the most of everyday with Google Calendar.    38267947
# 302  MORE THAN A WOMAN still available in paperback...    16681111
# 290  Born in Boston.Went to Hollywood at 18. 16 yea...   128956175
# 296  Carry The News: The OFFICIAL David Bowie twitt...    40139016
# 236              Actions designed for maximum outrage.     5943622
# 374  Host of “Unsung Science” podcast; "CBS Sunday ...     9534522
# 75   #AI Expert, CEO of 创新工场 @sinovationvc, former ...    50940456
# 403  Sunshine, Yahoo, Google, San Franciscan, Wisco...    17503180
# 98   Host of Lex Fridman Podcast.\nResearch Scienti...   427089628
# 323  Get the latest Android news, best practices, l...    93711247
# 372  Philanthropist, businesswoman, & global advoca...   161801527
# 241  The only non-profit-backed, people-first brows...     2142731
# 423                                                       17220934
# 368  Your friendly neighborhood NASA Mars rover. Ex...    15473958
# 140  I used to work for the government. Now I work ...  2916305152
# 415  Meta is helping build a future where people ha...     2425151
# 401  Welcome to the official twitter page of the Of...    20609518
# 263  Breaking news alerts and updates from the BBC....     5402612
#
#                         location                        name        username  \
# 342                      Houston           Scientific Python        SciPyTip
# 320                          Web                      Django   djangoproject
# 204                         MSRI                 Numberphile     numberphile
# 400                 New York, NY                Joel Spolsky         spolsky
# 89             San Francisco, CA                 Kent Beck 🌻        KentBeck
# 12                           NaN                 Tim Sweeney  TimSweeneyEpic
# 377   The Hague, The Netherlands                  Wim de Bie        wimdebie
# 148          Somewhere in London               Terry Gilliam    TerryGilliam
# 363            Hudson Valley, NY                  John Resig         jeresig
# 19                           NaN              Randall Munroe            xkcd
# 240                     Internet                     Mozilla         mozilla
# 383            San Francisco, CA                Drew Houston     drewhouston
# 410                       Global             Talks at Google   talksatgoogle
# 252                   Twitter HQ         Twitter Open Source      TwitterOSS
# 404         Austria & California                    twidroyd        twidroyd
# 448                  Seattle, WA               Werner Vogels          Werner
# 277                          NaN                Michael Dorn         akaWorf
# 90                        Boston               Martin Fowler    martinfowler
# 361                Brookline, MA                   Lessig 🇺🇦          lessig
# 360                       Boston             Tim Berners-Lee  timberners_lee
# 153    USA + Canada + UK + India              Girls Who Code    GirlsWhoCode
# 304                          NaN                    Coursera        coursera
# 391        Everywhere Python is!  Python Software Foundation          ThePSF
# 322            San Francisco, CA                         EFF             EFF
# 387               Washington, DC                  Matt Cutts       mattcutts
# 112                Cambridge, UK                Raspberry Pi    Raspberry_Pi
# 190                 New York, NY              Samantha Power      AmbPower44
# 139              Los Angeles, CA               Simone Giertz    SimoneGiertz
# 412  Faubourg Marigny, Louisiana               DaveJMatthews   DaveJMatthews
# 293              Los Angeles, CA               Grant Imahara    grantimahara
# 375                     Argleton              Eric Weinstein  EricRWeinstein
# 409                  Atlanta, GA                 CDC_eHealth     CDC_eHealth
# 281                          NaN             Google Calendar  googlecalendar
# 302                          NaN               Caitlin Moran    caitlinmoran
# 290           Mostly Los Angeles               Leonard Nimoy    TheRealNimoy
# 296                          NaN        David Bowie Official  DavidBowieReal
# 236               Menlo Park, CA             Marc Andreessen          pmarca
# 374                          USA                 David Pogue           Pogue
# 75                Beijing, China                  Kai-Fu Lee        kaifulee
# 403            San Francisco, CA                marissamayer    marissamayer
# 98                           NaN                 Lex Fridman      lexfridman
# 323            Mountain View, CA          Android Developers      AndroidDev
# 372                  Seattle, WA        Melinda French Gates    melindagates
# 241           All over the world                   Firefox 🔥         firefox
# 423                Nashville, TN                     Al Gore          algore
# 368            Gale Crater, Mars             Curiosity Rover   MarsCuriosity
# 140                          NaN              Edward Snowden         Snowden
# 415                    Metaverse                        Meta            Meta
# 401            Dharamsala, India                  Dalai Lama       DalaiLama
# 263                   London, UK           BBC Breaking News     BBCBreaking
#
#      followers_count  following_count  tweet_count  listed_count  subscriber
# 342           161528               17         7027          3123    15804774
# 320           165249               69          588          2470    15804774
# 204           172377              140         5260          1871    15804774
# 400           178228              603         7759          5940    15804774
# 89            185191              822        16301          5384    15804774
# 12            194957              285        12910          1479    15804774
# 377           211671               46         2693          1674    15804774
# 148           231762               26          796          1881    15804774
# 363           257120             2649        10252          9168    15804774
# 19            266488                1          742          1950    15804774
# 240           279665             3849        15244          3815    15804774
# 383           282093              554          495          3362    15804774
# 410           314389              650         2802          3965    15804774
# 252           321161               43         5185          2233    15804774
# 404           326330                7          336          3304    15804774
# 448           330668              209        11175          4678    15804774
# 277           335382              253         4189          3053    15804774
# 90            342557              257        10228          8086    15804774
# 361           346191              402        15810          8298    15804774
# 360           358864              702         1079         10258    15804774
# 153           378746             8157        17335          4395    15804774
# 304           479141              482         9773          6910    15804774
# 391           489400              115         6175          5967    15804774
# 322           506988             1087        35076         14306    15804774
# 387           507877             1443        32352         16023    15804774
# 112           542327             1188        41622          7733    15804774
# 190           551170              672         5628             0    15804774
# 139           551371             1718         6541          2253    15804774
# 412           593487                2         2170          6308    15804774
# 293           596069              445        12499         11785    15804774
# 375           694926              988        18901          5038    15804774
# 409           698491              153         7483          7750    15804774
# 281           796305              137        14668          8271    15804774
# 302           878357             2875        14453          5791    15804774
# 290           893247               21         1730             0    15804774
# 296           984357              588         2314          5177    15804774
# 236          1103489            20597         3060         15177    15804774
# 374          1291963             1861        12653         18604    15804774
# 75           1517526              643         3655          6182    15804774
# 403          1544248              345         1561         14285    15804774
# 98           1756189                2         2304          5671    15804774
# 323          2183472              381         6090         16356    15804774
# 372          2566115              571         4076          8537    15804774
# 241          2589968              494        45821         22876    15804774
# 423          2982256               42         3032         35511    15804774
# 368          4350021              171         4030         26549    15804774
# 140          5322232                1         7208         23004    15804774
# 415         13860963              719        15848         44462    15804774
# 401         19257637                0         1829         72780    15804774
# 263         51250069                3        38356        148814    15804774

# %%
seed_users = client.get_users(usernames=["wesmckinn", "honnibal", "_inesmontani", "pwang"]).data

# %%
seed_ids = [user.id for user in seed_users]

# %%
subscription_frames = []
for seed_id in seed_ids: 
    subscriptions_df = get_subscriptions_df(seed_id)
    subscription_frames.append(subscriptions_df)
# Out:
# /tmp/ipykernel_2108/1111235787.py:6: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   subscriptions_df = pd.concat(subscription_frames, gvr_subscriptions_df)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 6
#       3     subscriptions_df = get_subscriptions_df(seed_id)
#       4     subscription_frames.append(subscriptions_df)
# ----> 6 subscriptions_df = pd.concat(subscription_frames, gvr_subscriptions_df)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:369, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     147 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     148 def concat(
#     149     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     158     copy: bool = True,
#     159 ) -> DataFrame | Series:
#     160     """
#     161     Concatenate pandas objects along a particular axis.
#     162
#    (...)
#     367     1   3   4
#     368     """
# --> 369     op = _Concatenator(
#     370         objs,
#     371         axis=axis,
#     372         ignore_index=ignore_index,
#     373         join=join,
#     374         keys=keys,
#     375         levels=levels,
#     376         names=names,
#     377         verify_integrity=verify_integrity,
#     378         copy=copy,
#     379         sort=sort,
#     380     )
#     382     return op.get_result()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:497, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     495     axis = DataFrame._get_axis_number(axis)
#     496 else:
# --> 497     axis = sample._get_axis_number(axis)
#     499 # Need to flip BlockManager axis in the DataFrame special case
#     500 self._is_frame = isinstance(sample, ABCDataFrame)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:555, in NDFrame._get_axis_number(cls, axis)
#     551 @final
#     552 @classmethod
#     553 def _get_axis_number(cls, axis: Axis) -> int:
#     554     try:
# --> 555         return cls._AXIS_TO_AXIS_NUMBER[axis]
#     556     except KeyError:
#     557         raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'DataFrame'

# %%
subscriptions_df = pd.concat(subscription_frames)
subscriptions_df = pd.concat([subscriptions_df, gvr_subscriptions_df])
subscriptions_df.to_parquet("subscriptions.parquet")

# %% [markdown]
# We would be interested in anyone that at least 3 of these people follow. We don't need network analysis for this one, we can just look at counts by id. There are 68 accounts followed by at least 3 of their seeds; this may be a manageable number to work with.

# %%
shared_subscribers = subscriptions_df.id.value_counts()
shared_subscribers = shared_subscribers[shared_subscribers > 2].index
len(shared_subscribers)
# Out:
# 68

# %% [markdown]
# Let's take a closer look at these individuals. As we know already that they're in both sets, we'll look at them in GVR's subscriptions. There are a mix of people and organizations in the list. We are more interested in the people. Of those people, we are more interested, for this analysis, in people who mention python in their bios. We have several directions we could take from here:
# - Jake VanderPlaas, if we were interested in Astronomical / Scientific Python
# - Fernando Perez, creator of iPython, if we are interested in the Jupyter community
#
# We might also be interested in the accounts that have the largest number of followers, as it implies some amount of influence in the community, especially if the number of people they are following is realtively low. After exploring a bit I'm interested in Jacob Kaplan-Moss, who was heavily involved with Django. Django is a website framework and one of the more popular uses of Python.

# %%
subscriptions_df[subscriptions_df.id.isin(shared_subscribers)].groupby(["id", "username", "name"])[["followers_count", "following_count"]].min()
# Out:
#                                                       followers_count  \
# id                 username       name
# 25103              jessitron      Jessica Joy Kerr              37994
# 765548             hmason         Hilary Mason                 128902
# 803694             mikeolson      Mike Olson 🇺🇸                 25111
# 817083             EricaJoy       EricaJoy                     124195
# 823083             migueldeicaza  Miguel de Icaza               88127
# ...                                                               ...
# 2543588034         clattner_llvm  Chris Lattner                 65353
# 3422200198         spacy_io       spaCy                         24749
# 3562121415         RealSexyCyborg Naomi Wu 机械妖姬                221819
# 794723912189775872 vorpalsmith    Nathaniel J. Smith             2954
# 911297187664949248 JeffDean       Jeff Dean (@🏡)               221995
#
#                                                       following_count
# id                 username       name
# 25103              jessitron      Jessica Joy Kerr               2426
# 765548             hmason         Hilary Mason                   2053
# 803694             mikeolson      Mike Olson 🇺🇸                   232
# 817083             EricaJoy       EricaJoy                       1067
# 823083             migueldeicaza  Miguel de Icaza                4106
# ...                                                               ...
# 2543588034         clattner_llvm  Chris Lattner                   149
# 3422200198         spacy_io       spaCy                            23
# 3562121415         RealSexyCyborg Naomi Wu 机械妖姬                  2913
# 794723912189775872 vorpalsmith    Nathaniel J. Smith              210
# 911297187664949248 JeffDean       Jeff Dean (@🏡)                 5097
#
# [68 rows x 2 columns]

# %%
subscriptions_df[subscriptions_df.id.isin(shared_subscribers)].groupby(["id", "username", "name"])[["followers_count", "following_count"]].min()
# Out:
#                                                       followers_count  \
# id                 username       name
# 25103              jessitron      Jessica Joy Kerr              37994
# 765548             hmason         Hilary Mason                 128902
# 803694             mikeolson      Mike Olson 🇺🇸                 25111
# 817083             EricaJoy       EricaJoy                     124195
# 823083             migueldeicaza  Miguel de Icaza               88127
# ...                                                               ...
# 2543588034         clattner_llvm  Chris Lattner                 65353
# 3422200198         spacy_io       spaCy                         24749
# 3562121415         RealSexyCyborg Naomi Wu 机械妖姬                221819
# 794723912189775872 vorpalsmith    Nathaniel J. Smith             2954
# 911297187664949248 JeffDean       Jeff Dean (@🏡)               221995
#
#                                                       following_count
# id                 username       name
# 25103              jessitron      Jessica Joy Kerr               2426
# 765548             hmason         Hilary Mason                   2053
# 803694             mikeolson      Mike Olson 🇺🇸                   232
# 817083             EricaJoy       EricaJoy                       1067
# 823083             migueldeicaza  Miguel de Icaza                4106
# ...                                                               ...
# 2543588034         clattner_llvm  Chris Lattner                   149
# 3422200198         spacy_io       spaCy                            23
# 3562121415         RealSexyCyborg Naomi Wu 机械妖姬                  2913
# 794723912189775872 vorpalsmith    Nathaniel J. Smith              210
# 911297187664949248 JeffDean       Jeff Dean (@🏡)                 5097
#
# [68 rows x 2 columns]

# %%
jacobian_subscriptions_df = get_subscriptions_df(18824526)

# %% [markdown]
# Having done so, we can now see some accounts that are followed by all 3 individuals. There are 6 accounts in total. One of these is for Jessica McKellar, who I recognize as a major contributor to the Twisted python library. I did a little research and saw that she was also at one point head of the Python Software Foundation. Interestingly, a lot of the individuals on the list have very small subscription accounts. The exception is Nick Coghlan, a CPython developer. There is also an indivdual, Alex Gaynor, who doesn't subscribe to anyone, but to whom many people are subscribed. This is much more the pattern of a media organization than a person, which is most curious. Between all these individuals, there are just over 4500 subscriptions. Let's get 'em all and call it the end of the day for the source of our network.

# %%
follows_three = pd.concat([jacobian_subscriptions_df, gvr_subscriptions_df, wes_subscriptions_df]).id.value_counts()
follows_three = follows_three[follows_three > 2].index
len(follows_three)
jacobian_subscriptions_df[jacobian_subscriptions_df.id.isin(follows_three)]
# Out:
#                                           description         id  \
# 16                       CTO, https://t.co/FESdoVX9di   24945605
# 19  Python, software, @coveragepy, typography, jug...   16273417
# 29  chef ➡️ developer ➡️ keynote speaker & enginee...   17213939
# 34  CPython core developer, software architect @Tr...  261665936
# 45             Python core developer; snarky Canadian   14428320
# 49  software resilience engineer, and generalist t...   14635493
#
#                        location              name         username  \
# 16            San Francisco, CA  Jessica McKellar  jessicamckellar
# 19                       Boston    Ned Batchelder           nedbat
# 29              🎶 Nashville, TN    adriennefriend   adriennefriend
# 34  Brisbane, AU (Turrbal land)      Nick Coghlan     ncoghlan_dev
# 45  Vancouver, British Columbia      Brett Cannon         brettsky
# 49                         here       Alex Gaynor      alex_gaynor
#
#     followers_count  following_count  tweet_count  listed_count  subscriber
# 16            15291              339         1046           521    18824526
# 19            32189              162         9175           660    18824526
# 29             4794             1135        36507           245    18824526
# 34             9713             2547        40207           447    18824526
# 45            17953              326        16319           574    18824526
# 49            11730                0          114           769    18824526

# %%
subscriber_frames = []
for subscriber in jacobian_subscriptions_df.query("""following_count > 0""")[jacobian_subscriptions_df.id.isin(follows_three)].id.values:
    subscriber_frames.append(get_subscriptions_df(subscriber))
subscriptions_df = pd.concat(subscriber_frames)
# Out:
# /tmp/ipykernel_750/1827446070.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   for subscriber in jacobian_subscriptions_df.query("""following_count > 0""")[jacobian_subscriptions_df.id.isin(follows_three)].id.values:

# %%
subscriptions_df = pd.concat([
    gvr_subscriptions_df,
    wes_subscriptions_df,
    jacobian_subscriptions_df,
    subscriptions_df
])
subscriptions_df
# Out:
#                                            description          id  \
# 0    I work @Microsoft, making Python more awesome ...    14076724
# 1    Intl. Relations & MPP Grad 🌍 noob intersection...   187196955
# 2    Creator of @datasetteproj, co-creator Django. ...       12497
# 3    Partner Software Architect at Microsoft on .NE...    19481808
# 4    The #1 Python-focused podcast covering the peo...  3098427092
# ..                                                 ...         ...
# 321      Working on Python infrastructure at Instagram    17147516
# 322  software resilience engineer, and generalist t...    14635493
# 323              Engineer, Cyclist, Pythonista, Foodie    38579562
# 324                                                       36183197
# 325  mediocre and proud; he/him; some ways I might ...    18824526
#
#               location                        name         username  \
# 0          Redmond, WA                    John Lam         john_lam
# 1               Berlin  Camila Gutiérrez (she/her)  Mariacamilagl30
# 2    San Francisco, CA              Simon Willison           simonw
# 3              Redmond           David Fowler 🇧🇧🇺🇸        davidfowl
# 4     Portland, OR USA         Talk Python Podcast       TalkPython
# ..                 ...                         ...              ...
# 321        Seattle, WA               Dino Viehland     DinoViehland
# 322               here                 Alex Gaynor      alex_gaynor
# 323          Vancouver          Dr. Doug Latornell       dlatornell
# 324              Idaho              Whitney Cannon         cannonwe
# 325             Oregon                    jacobian         jacobian
#
#      followers_count  following_count  tweet_count  listed_count  subscriber
# 0               4406              586         6182           294    15804774
# 1                695              444          259             9    15804774
# 2              41365             5173        41097          1594    15804774
# 3             103781             1319        61351          1607    15804774
# 4              61467             4043         6076          1342    15804774
# ..               ...              ...          ...           ...         ...
# 321              440              134          306            32    14428320
# 322            11730                0          114           769    14428320
# 323              180              442         1416            14    14428320
# 324                2                0            2             0    14428320
# 325            14568               50        24101           804    14428320
#
# [5962 rows x 10 columns]

# %%
subscriptions_df.subscriber.nunique()
# Out:
# 8

# %% [markdown]
# There are just under 6000 subscriptions in our fledgling network for about 5200 individuals and 8 seeds. Time to bring in networkx!

# %%
import networkx as nx

python_twitterverse = nx.from_pandas_edgelist(subscriptions_df, source="subscriber", target="id", create_using=nx.DiGraph())

# %% [markdown]
# I thought it would be nice to bring in the user attributes to associate with each node. I thought that would be as simple as removing our "subscriber" field from the subscriptions dataframe and dropping duplicates.  I had a surprise, though - in between my calls, the public metrics of certain users changed! This highlights the really dynamic nature of Twitter and is a cautionary tale about thinking it is possible to have a truly complete sense of the Python twitterverse, even with infinite computing power and no rate limits.

# %%
users_df = subscriptions_df.drop("subscriber", axis="columns").drop_duplicates().copy()
users_df[users_df.id==users_df[users_df.id.duplicated()].id.values[0]]
# Out:
#                                            description      id    location  \
# 446  Fun Stack Vibing. Started Xamarin, Mono, Gnome...  823083  boston, ma
# 163  Fun Stack Vibing. Started Xamarin, Mono, Gnome...  823083  boston, ma
# 71   Fun Stack Vibing. Started Xamarin, Mono, Gnome...  823083  boston, ma
#
#                 name       username  followers_count  following_count  \
# 446  Miguel de Icaza  migueldeicaza            88127             4107
# 163  Miguel de Icaza  migueldeicaza            88128             4107
# 71   Miguel de Icaza  migueldeicaza            88129             4107
#
#      tweet_count  listed_count
# 446       100887          3417
# 163       100887          3417
# 71        100887          3417

# %% [markdown]
# We drop duplicates based on the id column only, then set the index for the frame to id. This lets us make a dictionary mapping user ids to their attributes, which is what networkx needs from us.

# %%
users_df = users_df.drop_duplicates(subset=["id"], keep="last")
users_df = users_df.set_index("id")
users_df = users_df.fillna("Not Provided")
users_dict = users_df.to_dict(orient="index")
id2user_dict = users_df["username"].to_dict()

# %% [markdown]
# We can now set attributes for our nodes. We also relabel them to use the usernames instead of ids, which will make our graph a little easier to play with.

# %%
users_df[users_df.username=="dongheena92"]
# Out:
#                                                            description  \
# id
# 1169287827521015808  SDE @ Line corp & CPython Core-dev: Opinions a...
#
#                          location         name     username  followers_count  \
# id
# 1169287827521015808  Not Provided  Dong-hee Na  dongheena92              760
#
#                      following_count  tweet_count  listed_count
# id
# 1169287827521015808              188          863            11

# %%
users_dict[users_df[users_df.username=="dongheena92"].index.values[0]]
# Out:
# {'description': 'SDE @ Line corp & CPython Core-dev: Opinions are my own not my employer',
#  'location': 'Not Provided',
#  'name': 'Dong-hee Na',
#  'username': 'dongheena92',
#  'followers_count': 760,
#  'following_count': 188,
#  'tweet_count': 863,
#  'listed_count': 11}

# %%
# enhance nodes by adding user details

nx.set_node_attributes(python_twitterverse, users_dict)
nx.relabel_nodes(python_twitterverse, users_df["username"].to_dict(), copy=False)

# %%
python_twitterverse.nodes()["dongheena92"]
# Out:
# {'description': 'SDE @ Line corp & CPython Core-dev: Opinions are my own not my employer',
#  'location': 'Not Provided',
#  'name': 'Dong-hee Na',
#  'username': 'dongheena92',
#  'followers_count': 760,
#  'following_count': 188,
#  'tweet_count': 863,
#  'listed_count': 11}

# %% [markdown]
# It's an awfully big network to work with. It does make a beautiful graph drawing, for sure, though my computer couldn't really handle the load. I did notice, before it gave up, that most of the nodes in the network only have one connection to the seeds that we chose. We can significantly reduce the number of nodes in our network by removing anyone who only has that one connection. We are now down to 505 nodes!

# %%
python_degree = python_twitterverse.degree()
single_nodes = [node for node in python_twitterverse if python_degree[node] == 1]
python_twitterverse.remove_nodes_from(single_nodes)
len(python_twitterverse)
# Out:
# 505

# %%
nx.get_node_attributes(python_twitterverse, "location")
# Out:
# {'maintainerati': 'A bike shed',
#  'jreback': 'Not Provided',
#  'necaris': 'Washington, D.C.',
#  'MitchellBaker': 'Not Provided',
#  'mxsash': 'she/her',
#  'dmoisset': 'London, England',
#  'matthew_d_green': 'Baltimore, MD',
#  'TheASF': 'Worldwide',
#  'andrewgodwin': 'Denver, CO, USA',
#  'GaelVaroquaux': 'Paris, France',
#  'pyconca': 'Canada',
#  'TimirahJ': 'Los Angeles, CA',
#  'BigDataBorat': 'Алматы',
#  'OpenSourceOrg': 'Palo Alto, CA',
#  'webology': 'Lawrence, KS',
#  'drfeifei': 'Stanford, CA, U.S.A.',
#  'gjbernat': 'Los Angeles, CA',
#  'etrepum': 'San Francisco, CA',
#  'stefanvdwalt': 'Truckee, California',
#  'kushaldas': 'Sweden',
#  'tarah': '(🇺🇸)🇮🇹🇫🇷🇬🇧',
#  'berkerpeksag': 'Helsinki, Finland',
#  'katie_k7r': 'Austin, TX',
#  'ftrain': 'Brooklyn, NY',
#  'OssAnna16': 'London, England 🇬🇧',
#  'juliaelman': 'Not Provided',
#  'kf': 'Portland, OR',
#  'corbett': 'Sierra Madre, CA',
#  'joeerl': 'Sweden',
#  'mariatta': 'Port Moody, British Columbia',
#  'PyCaribbean': 'Santo Domingo, DR',
#  'aprilwensel': 'Encinitas, CA',
#  'djangogirls': 'The World!',
#  'fwiles': 'Lawrence, KS',
#  'alicegoldfuss': '/usr/local/sin',
#  'PyData': 'Austin, TX',
#  'JukkaLeh': 'Cambridge, UK',
#  'jess_ingrass': 'New York, USA',
#  'quansightai': 'Not Provided',
#  'betswaliszewski': 'California',
#  'hiwearespiders': 'Everywhere',
#  'gergdotca': 'Montreal',
#  'raymondh': 'Austin, TX',
#  'cyen': 'Not Provided',
#  'bostonpython': 'Boston!',
#  'zeynep': 'floating in a most peculiar way',
#  'rikkiends': 'Raleigh, NC ',
#  'vboykis': 'Philadelphia',
#  'skippyhammond': 'Melbourne',
#  'migueldeicaza': 'boston, ma',
#  'MissPhilbin': 'Cambridge, England',
#  'giovannibajo': 'Firenze, Italy',
#  'kjam': 'Berlin, Germany',
#  'yarkot': 'Not Provided',
#  'jaykreps': 'Palo Alto, California',
#  'LorenaABarba': 'Washington, DC',
#  'lorencrary': 'Not Provided',
#  'pyconpune': 'Pune, India',
#  'flowerhack': 'Not Provided',
#  'hynek': 'Berlin, Germany',
#  'Skud': 'Not Provided',
#  'clattner_llvm': 'Not Provided',
#  'haikuginger': 'Not Provided',
#  'EFF': 'San Francisco, CA',
#  'marlene_zw': 'Not Provided',
#  'svvitale': 'Denver, CO',
#  'PythonHPC': 'United States of America ',
#  'anweshasrkr': 'Stockholm, Sweden',
#  'RonaldOussoren': 'The Netherlands',
#  'tambryantbutow': 'Silicon Valley to Miami',
#  'KojoIdrissa': 'Houston, TX',
#  'jessejiryudavis': 'East Village, New York City',
#  'pycon': 'Not Provided',
#  'estark37': 'San Francisco Bay Area',
#  'Mbussonn': 'France',
#  'signalapp': 'Not Provided',
#  'krisnova': 'San Francisco, CA',
#  'pythonbytes': 'Portland, OR',
#  'catherinedevlin': 'Dayton, OH',
#  'jorendorff': 'Nashville, TN',
#  'opencollect': 'Worldwide',
#  'antrod': 'Cambridge, MA',
#  'olasitarska': 'London, UK',
#  'pauloxnet': 'Pescara, Italy',
#  'Yhg1s': 'Not Provided',
#  'attacus_au': "Shady Hades' Weekend Retreat",
#  'CalebSmithNC': 'North Carolina',
#  'hannawallach': 'Brooklyn, NY',
#  'wolever': 'Montréal, Québec, Canada',
#  'timberners_lee': 'Boston',
#  'divinetechygirl': '404•☁️• 🐍 but always🗽',
#  'agjhnsn': 'Not Provided',
#  'kantrn': 'Bay Area Containment Zone',
#  'tidelift': 'Boston, MA',
#  'EBreathes': 'brain hell',
#  'twistedmatrix': 'Not Provided',
#  'cecilycarver': 'Seattle',
#  'offby1': 'Seattle',
#  'josevalim': 'Kraków, Poland',
#  'KLdivergence': 'Chicago, IL',
#  'HackerNewsOnion': 'Mountain Dew, CA',
#  'shanselman': 'Portland, Oregon',
#  'ballingt': 'Not Provided',
#  'MarsCuriosity': 'Gale Crater, Mars',
#  'doughellmann': 'Not Provided',
#  'captainsafia': 'Seattle, WA',
#  'melaniearbor': 'Not Provided',
#  'gutworth': 'Not Provided',
#  'pradyunsg': 'London',
#  'JuliaLanguage': 'RT, Like, Follow ≠ Endorsment',
#  'paulhildebrandt': 'Southern California',
#  'ethanhs': 'Berkeley, CA',
#  'jasoncwarner': 'Victoria BC',
#  'carljm': 'Rapid City, SD',
#  'moshezadka': 'California',
#  'EWDurbin': '🌈 - on a bike - they/them',
#  'bossjones': 'Gramercy Park, NY',
#  'cronym': 'San Francisco, CA',
#  'teoliphant': 'Austin, TX',
#  'ThatAndromeda': 'Somerville, MA',
#  'pathunstrom': 'Seattle, WA',
#  'ctitusbrown': 'My office is above a waiting room full of puppies. Davis, CA.',
#  'ThePSF': 'Everywhere Python is!',
#  'brainwane': 'Queens, NY',
#  'Remy_D': 'The Internet',
#  'revodavid': 'SF Bay Area, CA',
#  'jessicamckellar': 'San Francisco, CA',
#  'bluflowr': 'Austin',
#  'storming': 'Colorado',
#  'loooorenanicole': 'The Moon, Stars, & Cosmos.',
#  'PythonEvents': 'Python Land, Timezone: GMT',
#  'OnlyGirlInTech': 'Not Provided',
#  'birkenfeld': 'Bavaria, Germany',
#  'lakatialira': 'Mexico',
#  'skamille': 'Not Provided',
#  '_rsc': 'Not Provided',
#  'nelhage': 'San Francisco',
#  'CompSciFact': 'Not Provided',
#  'ewarren': 'Massachusetts',
#  'DinoViehland': 'Seattle, WA',
#  'mkennedy': 'Portland, OR',
#  'skimbrel': 'San Francisco, CA',
#  'drob': 'New York, NY',
#  'tannewt': 'Seattle, WA',
#  'takluyver': 'Not Provided',
#  'mestery': 'Woodbury, MN',
#  'brettsky': 'Vancouver, British Columbia',
#  'davorabbit': 'Not Provided',
#  'RealSexyCyborg': 'Shenzhen, China',
#  'gvanrossum': 'San Francisco Bay Area',
#  'MikeMcQuaid': 'Edinburgh, Scotland',
#  'ogrisel': 'Between Vannes & Paris, France',
#  'todogroup': 'Worldwide',
#  'adriennefriend': '🎶 Nashville, TN',
#  'mbostock': 'San Francisco, CA',
#  'cfactoid': 'Orlando, FL',
#  'gvwilson': 'Not Provided',
#  'jtauber': 'Boston, MA',
#  'tracymakes': 'Toronto, Ontario',
#  'evancz': 'Not Provided',
#  'liza': 'Somerville, MA',
#  'RaeKnowler': 'Zürich, Switzerland',
#  'anabalica': 'Seattle, WA',
#  'nayafia': 'Miami',
#  'BitIntegrity': 'Portland, OR',
#  'elthenerd': 'Toronto',
#  'wiredferret': 'Not Provided',
#  'jnuneziglesias': 'Santanyi, Mallorca',
#  'mrkn': 'iPhone: -77.528394,167.178132',
#  'KamalaHarris': 'Washington, DC',
#  'hmason': 'NYC',
#  'joshsimmons': 'Petaluma, CA; Coast Miwok land',
#  'h34th3r329': 'Medford, NJ',
#  'dwf': 'Brexitlandia',
#  'system76': 'Denver, CO',
#  'selenamarie': 'Portland, OR',
#  'holdenweb': 'Hastings, England',
#  'dhh': 'Not Provided',
#  'dontusethiscode': 'New York City',
#  'simonw': 'San Francisco, CA',
#  'kelseyhightower': 'Not Provided',
#  'SashaLaundy': 'Los Angeles, CA',
#  'ginatrapani': 'Brooklyn, New York, USA',
#  'miss_jwo': 'United Kingdom',
#  'kcunning': 'Washington, DC',
#  'edd': 'California',
#  'pytestdotorg': 'Not Provided',
#  'akaptur': 'Not Provided',
#  'ktou': '東京都杉並区',
#  'freakboy3742': 'Whadjuk Noongar Boodja',
#  'OpenAtMicrosoft': 'Redmond, USA',
#  'ivanov': 'Not Provided',
#  'dougnap': 'Not Provided',
#  'rustlang': 'Not Provided',
#  'callahad': 'Belfast, Northern Ireland',
#  'AishaBlake': 'Detroit, MI',
#  'chrisjrn': 'Petaluma, California, USA',
#  'ncoghlan_dev': 'Brisbane, AU (Turrbal land)',
#  'JennyBryan': 'Vancouver, BC',
#  '1st1': 'San Francisco, CA',
#  'gnprice': 'San Francisco, CA',
#  'mpirnat': 'Upstate Ohio',
#  'ThatDocsLady': 'Prague, Czech Republic',
#  'codewithanthony': 'Not Provided',
#  'dmofengineering': 'The Basement',
#  'adriarichards': 'Oakland, CA',
#  'PyBeeWare': 'The Hive.',
#  'starsandrobots': 'blue/green sphere',
#  'wholemilk': 'portland',
#  'christytoes': 'Seattle, WA',
#  'datametrician': 'Charleston, SC',
#  'QuantStack': '🇪🇺 Europe',
#  'AutomationPanda': 'The Triangle (NC)',
#  'SarahTaber_bww': 'Fayetteville, NC',
#  'NASAWebb': 'Lagrange Point 2',
#  'heatherchars': '🌇🏙🌆🌃',
#  'pyblogsal': 'London, England',
#  'jimbaker': 'Boulder, Colorado',
#  'PyTennessee': 'Nashville, TN',
#  'gpshead': 'Menlo Park, California',
#  'soltysh': 'Not Provided',
#  'Podcast__init__': 'Not Provided',
#  'erinspaced': 'Charlottesville, VA',
#  'ericholscher': 'Bend, Oregon',
#  'ashleymcnamara': 'Seattle, WA',
#  'hugs': 'Chicago (Oak Park)',
#  'ch_doig': 'Barcelona & Austin',
#  'zzzeek': 'northeast',
#  'o0karen0o': 'Not Provided',
#  'nnja': 'Not Provided',
#  'fijall': 'internet',
#  'PythonInsider': 'Not Provided',
#  'fsf': 'Boston, MA',
#  'emilyemorehouse': 'Denver, CO',
#  'jmayer': 'Italian Alps',
#  'nehanarkhede': 'Palo Alto',
#  'ehashdn': 'Seattle, WA',
#  'pytexas': 'Austin, TX',
#  'edXOnline': 'Cambridge, MA',
#  'pganssle': 'Boston, MA, USA',
#  'fwierzbicki': 'San Bruno, CA',
#  'birdsarah': 'Austin, TX',
#  'SylvainCorlay': '🇪🇺 Europe',
#  'davidism': 'San Diego, CA',
#  'tacaswell': 'NYC',
#  'justvanrossum': 'Haarlem, The Netherlands',
#  'jeffbarr': 'Seattle, WA',
#  'jacobian': 'Oregon',
#  'ProjectJupyter': 'The Future',
#  'qubitron': 'Issaquah, WA',
#  'bigreddot': 'Portland, OR',
#  'chriswilcox47': 'Seattle, WA',
#  'KentBeck': 'San Francisco, CA',
#  'PyOhio': 'Columbus, Ohio',
#  'DRMacIver': 'London, England',
#  'adrianholovaty': 'Amsterdam',
#  'asendecka': 'London, England',
#  'marinaz': 'Cambridge, MA',
#  'TalkPython': 'Portland, OR USA',
#  'KyleRayKelley': 'Santa Cruz, CA',
#  'tjguk': 'London, UK',
#  'mipsytipsy': 'San Francisco',
#  'kennethreitz42': 'Virgina, USA',
#  'asteracode': 'Naarm/Melbourne, Wurundjeri',
#  'ewa_jodlowska': 'Chicago, IL',
#  'DynamicWebPaige': '179°56′39.4″, +0°2′46.2″ 8k pc',
#  'SDisPater': 'Not Provided',
#  'billpollock': 'San Francisco, CA',
#  'juliaferraioli': 'Seattle, WA',
#  'b0rk': 'Montreal',
#  'baconandcoconut': 'Cambridge, MA',
#  'mikeolson': 'Berkeley, California',
#  'dstufft': 'Philadelphia, PA',
#  'vixter55': 'Bay Area',
#  'honeycombio': 'San Francisco, CA',
#  'jakevdp': 'Oakland CA',
#  'chriswithers13': 'UK',
#  'ameliagreenhall': 'Seattle',
#  'fperez_org': 'Berkeley, CA',
#  'lessig': 'Brookline, MA',
#  'donjayamanne': 'Not Provided',
#  'lfaraone': 'San Francisco, CA',
#  'nhuntwalker': 'Not Provided',
#  'EmilyGorcenski': 'Space',
#  'annaraven': 'Sillycon Valley',
#  '_ashfall_': 'San Francisco, CA',
#  'jhamrick': 'Cambridge, England',
#  'Captain_Joannah': 'New Brunswick, Canada',
#  'DawnWagesSays': ' Lenni Lenape land (Philly)',
#  'pyladies': 'Worldwide now!',
#  'voidspace': 'Northampton, UK',
#  'pwang': 'Austin, tx',
#  'A_single_bear': 'Forest',
#  'rlconley': 'Durham, NC',
#  'ChloeCondon': 'Oakland, CA',
#  'vihartvihart': 'Not Provided',
#  'treyhunner': 'San Diego, CA',
#  'jezdez': 'Germany, Europe',
#  'markramm': 'michigan',
#  'piamancini': 'Not Provided',
#  'lizthegrey': 'Unceded Gadigal+Musqueam land',
#  'DivaDanese': 'Western Ireland',
#  'notsolonecoder': 'Sydney',
#  'elliewix': 'Urbana, Illinois',
#  'amuellerml': 'Palo Alto',
#  'martinfowler': 'Boston',
#  'MDroettboom': 'Maryland, USA',
#  'shauna_gm': 'dc',
#  'jessfraz': "Falken's Maze",
#  'john_lam': 'Redmond, WA',
#  'jnd1er': 'UC San Diego, California',
#  'dabeaz': 'Chicago',
#  'amye': 'Portland, OR',
#  'yonatanzunger': 'Not Provided',
#  'dotpem': 'San Francisco, CA',
#  'amakarudze': 'Harare, Zimbabwe',
#  'starletdreaming': 'Brighton, England',
#  'amcasari': 'UTC - 5:00',
#  'lishali88': 'San Francisco, CA',
#  'mitsuhiko': 'Vienna, Austria',
#  'vlasovskikh': 'Saint Petersburg, Russia',
#  'RepKatiePorter': 'Irvine, CA and Washington, DC',
#  'elibendersky': 'Not Provided',
#  'wesmckinn': 'Nashville, TN',
#  'AOC': 'Bronx + Queens, NYC',
#  'pypi': 'The Cloud',
#  'pyscript_dev': 'Not Provided',
#  'di_codes': 'Philadelphia, PA',
#  'nedbat': 'Boston',
#  'jsteeleeditor': 'Providence, RI',
#  'm_holtermann': 'Berlin, Germany',
#  'alex_gaynor': 'here',
#  'sigmavirus24': 'Madison, WI',
#  'Raspberry_Pi': 'Cambridge, UK',
#  'honzakral': 'Prague, Czech Republic',
#  'nvie': 'The Netherlands',
#  'ramalhoorg': 'São Paulo, Brasil',
#  'AllenDowney': 'Boston, MA',
#  'devonzuegel': 'Miami Beach',
#  'JackieKazil': 'DC / Bradenton, FL / CoMo',
#  'alexstamos': 'San Francisco, CA',
#  'khinsen': 'Paris',
#  'SebastiaanZeeff': 'Rijswijk, The Netherlands',
#  'kjaymiller': 'San Diego, CA',
#  'tylerdave': 'Lakewood, OH, US',
#  'windupanna': 'Oakland',
#  'JoeBiden': 'Washington, DC',
#  'hawkieowl': 'Melbourne, Australia neé Perth',
#  'hpk42': 'Freiburg im Breisgau',
#  'jpcalderone': 'Not Provided',
#  'lhawthorn': 'On the wrong mute setting',
#  'paulweveritt': 'Fredericksburg, VA',
#  'judy2k': 'Edinburgh, Scotland',
#  'PHDcomics': 'Not Provided',
#  'idangazit': 'East Bay, CA',
#  'michelleful': 'Boston',
#  'anacondainc': 'Austin, TX',
#  'JoniTrythall': 'Northern Delaware',
#  'craigkerstiens': 'Albany, CA',
#  'DEVOPS_BORAT': 'Kazakhstan',
#  'moebio': 'California | NY |\xa0Spain',
#  'europython': 'Dublin & Online',
#  'pythoncookbook': 'Chicago, IL',
#  'matrixise': 'Charleroi, Belgique',
#  'fmdfrank': 'Not Provided',
#  'pypyproject': 'Not Provided',
#  'BetterAllies': 'Not Provided',
#  'mozilla': 'Internet',
#  'geekygirlsarah': 'Pittsburgh, PA',
#  'tylergoldencz': 'Prague, Czech Republic',
#  'timbray': 'Vancouver!',
#  'copyconstruct': 'San Francisco, CA',
#  'ErikRose': 'The Triangle',
#  'spolsky': 'New York, NY',
#  'left_pad': 'outside',
#  'garybernhardt': 'Seattle, WA',
#  'lara_hogan': 'Not Provided',
#  'brianokken': 'Portland, OR',
#  'bmispelon': 'Bø i Telemark, Norway',
#  'JoanneHastieArt': 'Vancouver, BC, Canada',
#  'EricRWeinstein': 'Argleton',
#  'dshafik': 'Washington, USA',
#  'Fineblkwoman': 'Atlanta GA',
#  'willmcgugan': 'Edinburgh, Scotland',
#  'ACLU': '50 states, DC, & Puerto Rico',
#  'djangoproject': 'Web',
#  'bunniestudios': 'Not Provided',
#  'veronica_hanus': 'New York, NY',
#  'diana_clarke': 'Edmonton, Alberta',
#  'patrickc': 'patrick@stripe.com',
#  'WillingCarol': 'San Diego',
#  'heddle317': 'San Francisco, CA',
#  'deray': 'Wakanda',
#  'pythonvscode': 'Not Provided',
#  'richturn_ms': 'Redmond, WA',
#  'laceynwilliams': 'Oregon, USA',
#  'pydanny': 'Los Angeles, CA / Houston, TX',
#  'BecomingDataSci': 'Harrisonburg, VA',
#  'jduims': 'Vancouver, British Columbia',
#  'ixek': 'Manchester, England',
#  'hypatiadotca': 'Ottawa/San Francisco',
#  'jessitron': 'St. Louis, MO',
#  'AndreaMcInnes21': 'Vancouver, British Columbia',
#  'defunkt': 'Not Provided',
#  'wescpy': 'Silicon Valley, CA, USA',
#  'clarecorthell': '🏄\u200d♀️ dena’ina & alutiiq land',
#  'AlSweigart': 'USA',
#  'gwenshap': 'San Jose, CA',
#  'saronyitbarek': 'Not Provided',
#  'ChangesetLLC': 'Astoria, New York',
#  'ironpython': 'Not Provided',
#  'noteable_io': 'Worldwide',
#  'cherylsabella': 'Not Provided',
#  'JillWohlner': 'St. Louis, MO',
#  'VictorStinner': 'France - he/his',
#  'richhickey': 'Not Provided',
#  'triketora': 'SFO✈️EWR✈️LHR',
#  'zooko': 'Boulder, Colorado, USA, Earth',
#  'guzdial': 'Ann Arbor, MI',
#  'fuzzychef': 'www.fuzzychef.com',
#  'NaomiCeder': 'Chicago',
#  'KentonVarda': 'Austin, TX',
#  'zooba': 'Scotland, UK',
#  'TwitterOSS': 'Twitter HQ',
#  'theavalkyrie': 'Atlanta, GA',
#  'BarackObama': 'Washington, DC',
#  'LeeFlower': 'Washington, DC',
#  'worrydream': 'Not Provided',
#  'baybryj': 'Bethlehem, PA',
#  'MichelleUfford': 'Anywhere, USA',
#  'audreyfeldroy': 'Los Angeles, CA / Houston, TX',
#  'evacide': 'Not Provided',
#  'r1chardj0n3s': 'Melbourne, Australia',
#  'shanecurcuru': 'Arlington, Massachusetts',
#  'asheeshlaroia': 'San Francisco, CA',
#  'SerhiyStorchaka': 'Ukraine',
#  'PyConNA': 'Windhoek, Namibia',
#  'pyconafrica': 'Africa',
#  'YhatHQ': 'Brooklyn, NY',
#  'easyaspython': 'Philadelphia, PA',
#  'lvh': '✶ ✶ ✶ ✶',
#  'glasnt': 'Not Provided',
#  'biglesp': 'Blackpool, Lancashire',
#  'arielwaldman': 'San Francisco',
#  'llanga': 'Poznań, Poland',
#  'malemburg': 'Düsseldorf, Germany',
#  'j1mfulton': 'Northern Neck of Virginia, USA',
#  'elprans': 'San Francisco',
#  'sarahjeong': 'Portland, OR',
#  'NeckbeardHacker': 'Third cubicle on the right.',
#  'ChristianHeimes': 'Hamburg, Germany',
#  'haxor': 'Not Provided',
#  'dongheena92': 'Not Provided',
#  'iff_or': 'Oregon, USA',
#  'roguelynn': 'New York, NY',
#  'theuni': 'Halle (Saale), Germany',
#  'glyph': 'here',
#  'ThePyPA': 'Your computer',
#  'nvaroqua': 'Grenoble',
#  'anthonybaxter': 'Sydney, Australia',
#  'club_is_open': 'Evanston, IL',
#  'pumpichank': 'Not Provided',
#  'nicoddemus': 'Florianópolis, Brazil',
#  'vorpalsmith': 'Not Provided',
#  'zulip': 'San Francisco, CA',
#  'sethmlarson': 'Minneapolis, MN',
#  'compassioncode': 'California, United States',
#  'incunabulista': 'Not Provided',
#  'ellisonbg': 'Not Provided',
#  'trustrachel': 'San Jose, CA',
#  'holdenkarau': 'san francisco,ca',
#  'AishaXBello': 'Not Provided',
#  'pamelafox': 'El Cerrito, CA',
#  'scopatz': 'Chicago, IL',
#  'phildini': 'Alameda, CA',
#  'writethedocs': 'PDX, PRG, AU, Worldwide',
#  'EricaJoy': 'Oakland, CA',
#  'annegentle': 'Austin, TX',
#  'Lukasaoz': 'Not Provided',
#  'enthought': 'Austin, TX',
#  'github': 'San Francisco, CA',
#  'VanL': 'San Antonio, TX',
#  'pjeby': 'Palm Beach County, Florida',
#  'chadwhitacre_': 'Not Provided',
#  'DalaiLama': 'Dharamsala, India',
#  'RainofTerra': 'San Francisco, CA',
#  'tiffani': 'California',
#  'FlipperPA': 'Philadelphia, PA',
#  'brandon_rhodes': 'Bluffton, Ohio',
#  'ModelViewMedia': 'San Francisco, CA',
#  'GMLudo': 'Brussels, Belgium',
#  'KatiMichel': 'The Internet',
#  'BiellaColeman': 'The internets',
#  'jeresig': 'Hudson Valley, NY',
#  'TomAugspurger': 'Des Moines, IA',
#  'CodeNewbies': 'Not Provided',
#  'ericsnowcrntly': 'Not Provided',
#  'shanley': 'Exile, Chicago ',
#  'juliasilge': 'Salt Lake City, UT',
#  'crisewing': 'Seattle, WA',
#  'anthonypjshaw': 'Sydney, Australia',
#  'wuoulf': 'Berlin, Europe',
#  'lrnrd': 'Berlin & remotely',
#  'rob_pike': 'Sydney, New South Wales',
#  'mrocklin': 'Austin, TX'}

# %%
nx.write_graphml(python_twitterverse, "python_twitterverse_d2.graphml")

# %% [markdown]
# ## Cliques - not just for Mean Girls!
#
# Because of the way we constructed our network, the most connections anyone can have would be 7.

# %%
for clique in nx.find_cliques(python_twitterverse.to_undirected()):
    if len(clique) > 6:
        print(clique)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 for clique in nx.find_cliques(python_twitterverse.to_undirected()):
#       2     if len(clique) > 6:
#       3         print(clique)
#
# NameError: name 'nx' is not defined

# %%
import networkx as nx
python_twitterverse = nx.read_graphml("python_twitterverse_d2.graphml")

# %%
python_twitterverse.degree()
# Out:
# DiDegreeView({'maintainerati': 2, 'jreback': 2, 'necaris': 3, 'MitchellBaker': 2, 'mxsash': 2, 'dmoisset': 2, 'matthew_d_green': 2, 'TheASF': 2, 'andrewgodwin': 3, 'GaelVaroquaux': 2, 'pyconca': 2, 'TimirahJ': 3, 'BigDataBorat': 2, 'OpenSourceOrg': 2, 'webology': 4, 'drfeifei': 2, 'gjbernat': 2, 'etrepum': 2, 'stefanvdwalt': 2, 'kushaldas': 4, 'tarah': 2, 'berkerpeksag': 2, 'katie_k7r': 2, 'ftrain': 2, 'OssAnna16': 2, 'juliaelman': 4, 'kf': 2, 'corbett': 2, 'joeerl': 2, 'mariatta': 4, 'PyCaribbean': 2, 'aprilwensel': 2, 'djangogirls': 2, 'fwiles': 4, 'alicegoldfuss': 2, 'PyData': 2, 'JukkaLeh': 2, 'jess_ingrass': 2, 'quansightai': 2, 'betswaliszewski': 3, 'hiwearespiders': 2, 'gergdotca': 2, 'raymondh': 3, 'cyen': 2, 'bostonpython': 2, 'zeynep': 2, 'rikkiends': 3, 'vboykis': 2, 'skippyhammond': 2, 'migueldeicaza': 3, 'MissPhilbin': 2, 'giovannibajo': 2, 'kjam': 2, 'yarkot': 3, 'jaykreps': 2, 'LorenaABarba': 3, 'lorencrary': 2, 'pyconpune': 2, 'flowerhack': 2, 'hynek': 2, 'Skud': 2, 'clattner_llvm': 2, 'haikuginger': 2, 'EFF': 2, 'marlene_zw': 4, 'svvitale': 2, 'PythonHPC': 2, 'anweshasrkr': 2, 'RonaldOussoren': 2, 'tambryantbutow': 2, 'KojoIdrissa': 2, 'jessejiryudavis': 4, 'pycon': 5, 'estark37': 2, 'Mbussonn': 3, 'signalapp': 2, 'krisnova': 2, 'pythonbytes': 2, 'catherinedevlin': 4, 'jorendorff': 4, 'opencollect': 2, 'antrod': 2, 'olasitarska': 3, 'pauloxnet': 2, 'Yhg1s': 5, 'attacus_au': 2, 'CalebSmithNC': 2, 'hannawallach': 2, 'wolever': 2, 'timberners_lee': 2, 'divinetechygirl': 2, 'agjhnsn': 2, 'kantrn': 2, 'tidelift': 2, 'EBreathes': 2, 'twistedmatrix': 2, 'cecilycarver': 2, 'offby1': 2, 'josevalim': 2, 'KLdivergence': 2, 'HackerNewsOnion': 2, 'shanselman': 2, 'ballingt': 3, 'MarsCuriosity': 2, 'doughellmann': 3, 'captainsafia': 3, 'melaniearbor': 3, 'gutworth': 2, 'pradyunsg': 2, 'JuliaLanguage': 2, 'paulhildebrandt': 3, 'ethanhs': 2, 'jasoncwarner': 2, 'carljm': 2, 'moshezadka': 3, 'EWDurbin': 3, 'bossjones': 2, 'cronym': 2, 'teoliphant': 4, 'ThatAndromeda': 2, 'pathunstrom': 2, 'ctitusbrown': 3, 'ThePSF': 7, 'brainwane': 2, 'Remy_D': 2, 'revodavid': 2, 'jessicamckellar': 56, 'bluflowr': 2, 'storming': 2, 'loooorenanicole': 5, 'PythonEvents': 2, 'OnlyGirlInTech': 2, 'birkenfeld': 2, 'lakatialira': 3, 'skamille': 2, '_rsc': 2, 'nelhage': 2, 'CompSciFact': 2, 'ewarren': 2, 'DinoViehland': 3, 'mkennedy': 4, 'skimbrel': 3, 'drob': 2, 'tannewt': 4, 'takluyver': 2, 'mestery': 2, 'brettsky': 171, 'davorabbit': 2, 'RealSexyCyborg': 2, 'gvanrossum': 208, 'MikeMcQuaid': 3, 'ogrisel': 3, 'todogroup': 2, 'adriennefriend': 210, 'mbostock': 2, 'cfactoid': 2, 'gvwilson': 3, 'jtauber': 3, 'tracymakes': 4, 'evancz': 2, 'liza': 2, 'RaeKnowler': 2, 'anabalica': 3, 'nayafia': 5, 'BitIntegrity': 2, 'elthenerd': 3, 'wiredferret': 2, 'jnuneziglesias': 2, 'mrkn': 2, 'KamalaHarris': 2, 'hmason': 4, 'joshsimmons': 2, 'h34th3r329': 2, 'dwf': 2, 'system76': 2, 'selenamarie': 3, 'holdenweb': 2, 'dhh': 2, 'dontusethiscode': 2, 'simonw': 5, 'kelseyhightower': 2, 'SashaLaundy': 2, 'ginatrapani': 2, 'miss_jwo': 2, 'kcunning': 4, 'edd': 2, 'pytestdotorg': 2, 'akaptur': 4, 'ktou': 2, 'freakboy3742': 4, 'OpenAtMicrosoft': 2, 'ivanov': 3, 'dougnap': 2, 'rustlang': 3, 'callahad': 2, 'AishaBlake': 2, 'chrisjrn': 2, 'ncoghlan_dev': 425, 'JennyBryan': 2, '1st1': 3, 'gnprice': 2, 'mpirnat': 4, 'ThatDocsLady': 2, 'codewithanthony': 2, 'dmofengineering': 2, 'adriarichards': 2, 'PyBeeWare': 2, 'starsandrobots': 2, 'wholemilk': 2, 'christytoes': 3, 'datametrician': 2, 'QuantStack': 2, 'AutomationPanda': 2, 'SarahTaber_bww': 2, 'NASAWebb': 2, 'heatherchars': 2, 'pyblogsal': 3, 'jimbaker': 2, 'PyTennessee': 3, 'gpshead': 2, 'soltysh': 2, 'Podcast__init__': 2, 'erinspaced': 2, 'ericholscher': 5, 'ashleymcnamara': 2, 'hugs': 2, 'ch_doig': 2, 'zzzeek': 2, 'o0karen0o': 2, 'nnja': 3, 'fijall': 2, 'PythonInsider': 4, 'fsf': 2, 'emilyemorehouse': 5, 'jmayer': 2, 'nehanarkhede': 2, 'ehashdn': 2, 'pytexas': 3, 'edXOnline': 2, 'pganssle': 3, 'fwierzbicki': 2, 'birdsarah': 2, ...
